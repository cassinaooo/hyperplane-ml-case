# %%
import pickle as pkl

import numpy as np
from tqdm import tqdm

# %%
with open("./data/norm_vendors_list.pkl", "rb") as f:
    norm_vendors_str = pkl.load(f)

# %%
norm_vendors_str[:5]
# Out:
# ['AAA GLASS MIRROR',
#  'AAA MAILBOX SALES SERVI',
#  'AAA OKLAHOMA',
#  'AAA OKLAHOMA MBR DUES',
#  'AAA STRIPING SEALING']

# %%
with open("./data/vendors_similarities.pkl", "rb") as f:
    similarities = pkl.load(f)

# %%
len(similarities), len(vendors_idx_to_name), len(vendors_name_to_idx)
# Out:
# (35821, 35821, 35821)

# %%
import scipy

# %%
sims_array = scipy.sparse.lil_matrix(
    (len(similarities), len(similarities)), dtype=float
)

# %%
sims_array
# Out:
# <35821x35821 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in List of Lists format>

# %%
similarities[0]
# Out:
# {'vendor_name': 'AAA GLASS MIRROR',
#  'others': [{'vendor_name': 'ATLAS GLASS MIRROR', 'sim': 0.8214285714285714},
#   {'vendor_name': 'CENTRAL GLASS MIRROR', 'sim': 0.8214285714285714},
#   {'vendor_name': 'CLOUSE GLASS MIRROR', 'sim': 0.8214285714285714},
#   {'vendor_name': 'DYER GLASS AND MIRROR', 'sim': 0.7857142857142857},
#   {'vendor_name': 'FOX GLASS MIRROR', 'sim': 0.8214285714285714},
#   {'vendor_name': 'GLASS MIRROR LLC', 'sim': 0.75}]}

# %%
for vendor_1 in tqdm(similarities):
    source_idx = vendors_name_to_idx[vendor_1["vendor_name"]]
    for vendor_2 in vendor_1["others"]:
        target_idx = vendors_name_to_idx[vendor_2["vendor_name"]]
        sims_array[source_idx, target_idx] = vendor_2["sim"]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35821/35821 [00:33<00:00, 1061.71it/s]

# %%
sims_array
# Out:
# <35821x35821 sparse matrix of type '<class 'numpy.float64'>'
# 	with 22484789 stored elements in List of Lists format>

# %%
del similarities  # about 7 Gigs

# %%
csr_matrix = scipy.sparse.csr_array(sims_array)

# %%
csr_matrix
# Out:
# <35821x35821 sparse array of type '<class 'numpy.float64'>'
# 	with 22484789 stored elements in Compressed Sparse Row format>

# %%
with open("./data/norm_vendors_csr_matrix.pkl", "wb") as f:
    pkl.dump(
        csr_matrix,
        f,
    )
